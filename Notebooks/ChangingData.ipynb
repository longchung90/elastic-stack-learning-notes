# %% [markdown]
# # Changing Data
#
# ## Objectives
# - Reindexing documents from a remote Elasticsearch cluster
# - Count documents in an index
# - Delete docs matching criteria (Delete by Query API)
# - **Useful**: data migration, consolidating environments, ugrading infrastucture, disaster recovery. (without export and import processes)
